# %%
import os
import hdf5storage
import scipy.io as sio

source_path = '/Users/elizabethnemeti/Desktop/data'
unlabeled_path = '/Users/elizabethnemeti/Desktop/unlabeled_data'

# Ensure the output directory exists
os.makedirs(unlabeled_path, exist_ok=True)

def extract_unlabeled_data(source_path, unlabeled_path):
    for root, dirs, files in os.walk(source_path):
        for file in files:
            if file.endswith('.mat') and file != '.DS_Store':
                source_file = os.path.join(root, file)
                try:
                    # Load the .mat file
                    data = hdf5storage.loadmat(source_file)
                    # Extract image data or other features needed for unsupervised learning
                    image_data = data['cjdata']['image']

                    # Create a new .mat file with only the image data (unlabeled)
                    new_filename = os.path.join(unlabeled_path, file)
                    sio.savemat(new_filename, {'image': image_data})

                except KeyError as e:
                    print(f"Missing expected data in {file}: {e}")
                except Exception as e:
                    print(f"Could not process {file}: {e}")

def verify_unlabeled_data(unlabeled_path):
    for file in os.listdir(unlabeled_path):
        if file.endswith('.mat'):
            try:
                # Load the .mat file
                data = sio.loadmat(os.path.join(unlabeled_path, file))
                # Check if only 'image' key exists
                if data.keys() == {'__header__', '__version__', '__globals__', 'image'}:
                    print(f"File {file} is successfully unlabeled.")
                else:
                    print(f"File {file} may still contain labels or unexpected data.")
            except Exception as e:
                print(f"Failed to verify {file}: {e}")

# Run the extraction function
extract_unlabeled_data(source_path, unlabeled_path)

# Verify the unlabeled data
verify_unlabeled_data(unlabeled_path)

print("Extraction and verification complete.")
# Out:
# File 259.mat is successfully unlabeled.
# File 1915.mat is successfully unlabeled.
# File 265.mat is successfully unlabeled.
# File 1097.mat is successfully unlabeled.
# File 503.mat is successfully unlabeled.
# File 517.mat is successfully unlabeled.
# File 1083.mat is successfully unlabeled.
# File 271.mat is successfully unlabeled.
# File 2561.mat is successfully unlabeled.
# File 1068.mat is successfully unlabeled.
# File 2213.mat is successfully unlabeled.
# File 1732.mat is successfully unlabeled.
# File 1054.mat is successfully unlabeled.
# File 701.mat is successfully unlabeled.
# File 1295.mat is successfully unlabeled.
# File 2944.mat is successfully unlabeled.
# File 2788.mat is successfully unlabeled.
# File 1281.mat is successfully unlabeled.
# File 926.mat is successfully unlabeled.
# File 2005.mat is successfully unlabeled.
# File 2011.mat is successfully unlabeled.
# File 2777.mat is successfully unlabeled.
# File 932.mat is successfully unlabeled.
# File 1256.mat is successfully unlabeled.
# File 1530.mat is successfully unlabeled.
# File 1242.mat is successfully unlabeled.
# File 2993.mat is successfully unlabeled.
# File 891.mat is successfully unlabeled.
# File 649.mat is successfully unlabeled.
# File 885.mat is successfully unlabeled.
# File 2818.mat is successfully unlabeled.
# File 675.mat is successfully unlabeled.
# File 113.mat is successfully unlabeled.
# File 1487.mat is successfully unlabeled.
# File 1493.mat is successfully unlabeled.
# File 107.mat is successfully unlabeled.
# File 2824.mat is successfully unlabeled.
# File 661.mat is successfully unlabeled.
# File 12.mat is successfully unlabeled.
# File 2617.mat is successfully unlabeled.
# File 1478.mat is successfully unlabeled.
# File 2165.mat is successfully unlabeled.
# File 846.mat is successfully unlabeled.
# File 1322.mat is successfully unlabeled.
# File 1444.mat is successfully unlabeled.
# File 2159.mat is successfully unlabeled.
# File 1450.mat is successfully unlabeled.
# File 1875.mat is successfully unlabeled.
# File 339.mat is successfully unlabeled.
# File 1685.mat is successfully unlabeled.
# File 311.mat is successfully unlabeled.
# File 477.mat is successfully unlabeled.
# File 463.mat is successfully unlabeled.
# File 305.mat is successfully unlabeled.
# File 1691.mat is successfully unlabeled.
# File 2415.mat is successfully unlabeled.
# File 488.mat is successfully unlabeled.
# File 1108.mat is successfully unlabeled.
# File 1646.mat is successfully unlabeled.
# File 1120.mat is successfully unlabeled.
# File 3044.mat is successfully unlabeled.
# File 1653.mat is successfully unlabeled.
# File 1647.mat is successfully unlabeled.
# File 2428.mat is successfully unlabeled.
# File 1121.mat is successfully unlabeled.
# File 2400.mat is successfully unlabeled.
# File 1109.mat is successfully unlabeled.
# File 2366.mat is successfully unlabeled.
# File 489.mat is successfully unlabeled.
# File 2414.mat is successfully unlabeled.
# File 462.mat is successfully unlabeled.
# File 1690.mat is successfully unlabeled.
# File 304.mat is successfully unlabeled.
# File 1848.mat is successfully unlabeled.
# File 310.mat is successfully unlabeled.
# File 1684.mat is successfully unlabeled.
# File 476.mat is successfully unlabeled.
# File 338.mat is successfully unlabeled.
# File 1874.mat is successfully unlabeled.
# File 1451.mat is successfully unlabeled.
# File 1323.mat is successfully unlabeled.
# File 1445.mat is successfully unlabeled.
# File 2164.mat is successfully unlabeled.
# File 2602.mat is successfully unlabeled.
# File 13.mat is successfully unlabeled.
# File 1479.mat is successfully unlabeled.
# File 106.mat is successfully unlabeled.
# File 660.mat is successfully unlabeled.
# File 674.mat is successfully unlabeled.
# File 1486.mat is successfully unlabeled.
# File 112.mat is successfully unlabeled.
# File 884.mat is successfully unlabeled.
# File 648.mat is successfully unlabeled.
# File 2992.mat is successfully unlabeled.
# File 1243.mat is successfully unlabeled.
# File 1257.mat is successfully unlabeled.
# File 2038.mat is successfully unlabeled.
# File 1531.mat is successfully unlabeled.
# File 1519.mat is successfully unlabeled.
# File 2776.mat is successfully unlabeled.
# File 2762.mat is successfully unlabeled.
# File 927.mat is successfully unlabeled.
# File 714.mat is successfully unlabeled.
# File 1280.mat is successfully unlabeled.
# File 2951.mat is successfully unlabeled.
# File 2945.mat is successfully unlabeled.
# File 1294.mat is successfully unlabeled.
# File 700.mat is successfully unlabeled.
# File 2979.mat is successfully unlabeled.
# File 2548.mat is successfully unlabeled.
# File 1727.mat is successfully unlabeled.
# File 2206.mat is successfully unlabeled.
# File 1069.mat is successfully unlabeled.
# File 2560.mat is successfully unlabeled.
# File 1082.mat is successfully unlabeled.
# File 516.mat is successfully unlabeled.
# File 270.mat is successfully unlabeled.
# File 264.mat is successfully unlabeled.
# File 502.mat is successfully unlabeled.
# File 1096.mat is successfully unlabeled.
# File 1900.mat is successfully unlabeled.
# File 1914.mat is successfully unlabeled.
# File 258.mat is successfully unlabeled.
# File 528.mat is successfully unlabeled.
# File 1916.mat is successfully unlabeled.
# File 272.mat is successfully unlabeled.
# File 514.mat is successfully unlabeled.
# File 1080.mat is successfully unlabeled.
# File 1094.mat is successfully unlabeled.
# File 500.mat is successfully unlabeled.
# File 266.mat is successfully unlabeled.
# File 2576.mat is successfully unlabeled.
# File 2562.mat is successfully unlabeled.
# File 299.mat is successfully unlabeled.
# File 1043.mat is successfully unlabeled.
# File 1057.mat is successfully unlabeled.
# File 1731.mat is successfully unlabeled.
# File 1282.mat is successfully unlabeled.
# File 702.mat is successfully unlabeled.
# File 1296.mat is successfully unlabeled.
# File 2947.mat is successfully unlabeled.
# File 2774.mat is successfully unlabeled.
# File 931.mat is successfully unlabeled.
# File 2006.mat is successfully unlabeled.
# File 925.mat is successfully unlabeled.
# File 1269.mat is successfully unlabeled.
# File 2760.mat is successfully unlabeled.
# File 1241.mat is successfully unlabeled.
# File 2748.mat is successfully unlabeled.
# File 2990.mat is successfully unlabeled.
# File 2984.mat is successfully unlabeled.
# File 1255.mat is successfully unlabeled.
# File 886.mat is successfully unlabeled.
# File 138.mat is successfully unlabeled.
# File 662.mat is successfully unlabeled.
# File 104.mat is successfully unlabeled.
# File 110.mat is successfully unlabeled.
# File 1484.mat is successfully unlabeled.
# File 676.mat is successfully unlabeled.
# File 2600.mat is successfully unlabeled.
# File 1309.mat is successfully unlabeled.
# File 845.mat is successfully unlabeled.
# File 2166.mat is successfully unlabeled.
# File 689.mat is successfully unlabeled.
# File 11.mat is successfully unlabeled.
# File 2614.mat is successfully unlabeled.
# File 1335.mat is successfully unlabeled.
# File 39.mat is successfully unlabeled.
# File 1321.mat is successfully unlabeled.
# File 448.mat is successfully unlabeled.
# File 306.mat is successfully unlabeled.
# File 1692.mat is successfully unlabeled.
# File 460.mat is successfully unlabeled.
# File 474.mat is successfully unlabeled.
# File 1686.mat is successfully unlabeled.
# File 312.mat is successfully unlabeled.
# File 2402.mat is successfully unlabeled.
# File 1651.mat is successfully unlabeled.
# File 3046.mat is successfully unlabeled.
# File 1137.mat is successfully unlabeled.
# File 1123.mat is successfully unlabeled.
# File 3052.mat is successfully unlabeled.
# File 1645.mat is successfully unlabeled.
# File 1644.mat is successfully unlabeled.
# File 3047.mat is successfully unlabeled.
# File 1136.mat is successfully unlabeled.
# File 2417.mat is successfully unlabeled.
# File 1678.mat is successfully unlabeled.
# File 2365.mat is successfully unlabeled.
# File 475.mat is successfully unlabeled.
# File 313.mat is successfully unlabeled.
# File 1687.mat is successfully unlabeled.
# File 1693.mat is successfully unlabeled.
# File 307.mat is successfully unlabeled.
# File 461.mat is successfully unlabeled.
# File 449.mat is successfully unlabeled.
# File 1446.mat is successfully unlabeled.
# File 1320.mat is successfully unlabeled.
# File 2629.mat is successfully unlabeled.
# File 878.mat is successfully unlabeled.
# File 38.mat is successfully unlabeled.
# File 1334.mat is successfully unlabeled.
# File 1452.mat is successfully unlabeled.
# File 850.mat is successfully unlabeled.
# File 10.mat is successfully unlabeled.
# File 688.mat is successfully unlabeled.
# File 844.mat is successfully unlabeled.
# File 2601.mat is successfully unlabeled.
# File 2167.mat is successfully unlabeled.
# File 1485.mat is successfully unlabeled.
# File 111.mat is successfully unlabeled.
# File 677.mat is successfully unlabeled.
# File 663.mat is successfully unlabeled.
# File 105.mat is successfully unlabeled.
# File 1491.mat is successfully unlabeled.
# File 893.mat is successfully unlabeled.
# File 139.mat is successfully unlabeled.
# File 1532.mat is successfully unlabeled.
# File 1254.mat is successfully unlabeled.
# File 918.mat is successfully unlabeled.
# File 2985.mat is successfully unlabeled.
# File 2749.mat is successfully unlabeled.
# File 1526.mat is successfully unlabeled.
# File 2007.mat is successfully unlabeled.
# File 2761.mat is successfully unlabeled.
# File 1268.mat is successfully unlabeled.
# File 924.mat is successfully unlabeled.
# File 930.mat is successfully unlabeled.
# File 2013.mat is successfully unlabeled.
# File 1297.mat is successfully unlabeled.
# File 703.mat is successfully unlabeled.
# File 1283.mat is successfully unlabeled.
# File 1730.mat is successfully unlabeled.
# File 1724.mat is successfully unlabeled.
# File 2563.mat is successfully unlabeled.
# File 298.mat is successfully unlabeled.
# File 1718.mat is successfully unlabeled.
# File 2577.mat is successfully unlabeled.
# File 501.mat is successfully unlabeled.
# File 1095.mat is successfully unlabeled.
# File 267.mat is successfully unlabeled.
# File 273.mat is successfully unlabeled.
# File 2588.mat is successfully unlabeled.
# File 1081.mat is successfully unlabeled.
# File 515.mat is successfully unlabeled.
# File 1917.mat is successfully unlabeled.
# File 529.mat is successfully unlabeled.
# File 511.mat is successfully unlabeled.
# File 277.mat is successfully unlabeled.
# File 263.mat is successfully unlabeled.
# File 2598.mat is successfully unlabeled.
# File 1091.mat is successfully unlabeled.
# File 505.mat is successfully unlabeled.
# File 1907.mat is successfully unlabeled.
# File 1913.mat is successfully unlabeled.
# File 539.mat is successfully unlabeled.
# File 1046.mat is successfully unlabeled.
# File 1720.mat is successfully unlabeled.
# File 2229.mat is successfully unlabeled.
# File 2215.mat is successfully unlabeled.
# File 288.mat is successfully unlabeled.
# File 1708.mat is successfully unlabeled.
# File 2201.mat is successfully unlabeled.
# File 1287.mat is successfully unlabeled.
# File 707.mat is successfully unlabeled.
# File 2942.mat is successfully unlabeled.
# File 1244.mat is successfully unlabeled.
# File 2759.mat is successfully unlabeled.
# File 2981.mat is successfully unlabeled.
# File 1250.mat is successfully unlabeled.
# File 1536.mat is successfully unlabeled.
# File 934.mat is successfully unlabeled.
# File 1278.mat is successfully unlabeled.
# File 920.mat is successfully unlabeled.
# File 2765.mat is successfully unlabeled.
# File 1495.mat is successfully unlabeled.
# File 101.mat is successfully unlabeled.
# File 2822.mat is successfully unlabeled.
# File 667.mat is successfully unlabeled.
# File 673.mat is successfully unlabeled.
# File 2188.mat is successfully unlabeled.
# File 115.mat is successfully unlabeled.
# File 1481.mat is successfully unlabeled.
# File 129.mat is successfully unlabeled.
# File 1456.mat is successfully unlabeled.
# File 1330.mat is successfully unlabeled.
# File 2639.mat is successfully unlabeled.
# File 28.mat is successfully unlabeled.
# File 868.mat is successfully unlabeled.
# File 1442.mat is successfully unlabeled.
# File 2163.mat is successfully unlabeled.
# File 698.mat is successfully unlabeled.
# File 14.mat is successfully unlabeled.
# File 1318.mat is successfully unlabeled.
# File 2611.mat is successfully unlabeled.
# File 2177.mat is successfully unlabeled.
# File 465.mat is successfully unlabeled.
# File 303.mat is successfully unlabeled.
# File 1697.mat is successfully unlabeled.
# File 1683.mat is successfully unlabeled.
# File 317.mat is successfully unlabeled.
# File 471.mat is successfully unlabeled.
# File 459.mat is successfully unlabeled.
# File 1873.mat is successfully unlabeled.
# File 1132.mat is successfully unlabeled.
# File 1654.mat is successfully unlabeled.
# File 3057.mat is successfully unlabeled.
# File 1640.mat is successfully unlabeled.
# File 1126.mat is successfully unlabeled.
# File 2407.mat is successfully unlabeled.
# File 1668.mat is successfully unlabeled.
# File 2375.mat is successfully unlabeled.
# File 2374.mat is successfully unlabeled.
# File 2412.mat is successfully unlabeled.
# File 1669.mat is successfully unlabeled.
# File 2360.mat is successfully unlabeled.
# File 1127.mat is successfully unlabeled.
# File 1133.mat is successfully unlabeled.
# File 1655.mat is successfully unlabeled.
# File 1866.mat is successfully unlabeled.
# File 458.mat is successfully unlabeled.
# File 316.mat is successfully unlabeled.
# File 470.mat is successfully unlabeled.
# File 464.mat is successfully unlabeled.
# File 1696.mat is successfully unlabeled.
# File 302.mat is successfully unlabeled.
# File 855.mat is successfully unlabeled.
# File 1319.mat is successfully unlabeled.
# File 15.mat is successfully unlabeled.
# File 2162.mat is successfully unlabeled.
# File 699.mat is successfully unlabeled.
# File 2604.mat is successfully unlabeled.
# File 1325.mat is successfully unlabeled.
# File 29.mat is successfully unlabeled.
# File 1443.mat is successfully unlabeled.
# File 1457.mat is successfully unlabeled.
# File 1331.mat is successfully unlabeled.
# File 896.mat is successfully unlabeled.
# File 128.mat is successfully unlabeled.
# File 672.mat is successfully unlabeled.
# File 1480.mat is successfully unlabeled.
# File 114.mat is successfully unlabeled.
# File 100.mat is successfully unlabeled.
# File 666.mat is successfully unlabeled.
# File 921.mat is successfully unlabeled.
# File 2002.mat is successfully unlabeled.
# File 1279.mat is successfully unlabeled.
# File 935.mat is successfully unlabeled.
# File 1251.mat is successfully unlabeled.
# File 2980.mat is successfully unlabeled.
# File 2758.mat is successfully unlabeled.
# File 1537.mat is successfully unlabeled.
# File 1523.mat is successfully unlabeled.
# File 1245.mat is successfully unlabeled.
# File 1292.mat is successfully unlabeled.
# File 706.mat is successfully unlabeled.
# File 712.mat is successfully unlabeled.
# File 1286.mat is successfully unlabeled.
# File 2957.mat is successfully unlabeled.
# File 2200.mat is successfully unlabeled.
# File 1709.mat is successfully unlabeled.
# File 2566.mat is successfully unlabeled.
# File 2572.mat is successfully unlabeled.
# File 289.mat is successfully unlabeled.
# File 1735.mat is successfully unlabeled.
# File 1047.mat is successfully unlabeled.
# File 2228.mat is successfully unlabeled.
# File 1721.mat is successfully unlabeled.
# File 538.mat is successfully unlabeled.
# File 1906.mat is successfully unlabeled.
# File 262.mat is successfully unlabeled.
# File 504.mat is successfully unlabeled.
# File 1090.mat is successfully unlabeled.
# File 510.mat is successfully unlabeled.
# File 276.mat is successfully unlabeled.
# File 1092.mat is successfully unlabeled.
# File 506.mat is successfully unlabeled.
# File 260.mat is successfully unlabeled.
# File 274.mat is successfully unlabeled.
# File 512.mat is successfully unlabeled.
# File 1086.mat is successfully unlabeled.
# File 1910.mat is successfully unlabeled.
# File 248.mat is successfully unlabeled.
# File 2558.mat is successfully unlabeled.
# File 1737.mat is successfully unlabeled.
# File 1723.mat is successfully unlabeled.
# File 1045.mat is successfully unlabeled.
# File 1079.mat is successfully unlabeled.
# File 704.mat is successfully unlabeled.
# File 1290.mat is successfully unlabeled.
# File 2941.mat is successfully unlabeled.
# File 2799.mat is successfully unlabeled.
# File 710.mat is successfully unlabeled.
# File 2969.mat is successfully unlabeled.
# File 1535.mat is successfully unlabeled.
# File 2982.mat is successfully unlabeled.
# File 1253.mat is successfully unlabeled.
# File 1521.mat is successfully unlabeled.
# File 2000.mat is successfully unlabeled.
# File 1509.mat is successfully unlabeled.
# File 923.mat is successfully unlabeled.
# File 2766.mat is successfully unlabeled.
# File 2772.mat is successfully unlabeled.
# File 2014.mat is successfully unlabeled.
# File 116.mat is successfully unlabeled.
# File 1482.mat is successfully unlabeled.
# File 670.mat is successfully unlabeled.
# File 2835.mat is successfully unlabeled.
# File 664.mat is successfully unlabeled.
# File 1496.mat is successfully unlabeled.
# File 102.mat is successfully unlabeled.
# File 2809.mat is successfully unlabeled.
# File 880.mat is successfully unlabeled.
# File 658.mat is successfully unlabeled.
# File 1441.mat is successfully unlabeled.
# File 1327.mat is successfully unlabeled.
# File 1333.mat is successfully unlabeled.
# File 1455.mat is successfully unlabeled.
# File 17.mat is successfully unlabeled.
# File 857.mat is successfully unlabeled.
# File 1469.mat is successfully unlabeled.
# File 472.mat is successfully unlabeled.
# File 314.mat is successfully unlabeled.
# File 300.mat is successfully unlabeled.
# File 1694.mat is successfully unlabeled.
# File 466.mat is successfully unlabeled.
# File 328.mat is successfully unlabeled.
# File 1125.mat is successfully unlabeled.
# File 3054.mat is successfully unlabeled.
# File 1643.mat is successfully unlabeled.
# File 3040.mat is successfully unlabeled.
# File 1131.mat is successfully unlabeled.
# File 2410.mat is successfully unlabeled.
# File 1119.mat is successfully unlabeled.
# File 499.mat is successfully unlabeled.
# File 2404.mat is successfully unlabeled.
# File 2363.mat is successfully unlabeled.
# File 2405.mat is successfully unlabeled.
# File 498.mat is successfully unlabeled.
# File 1118.mat is successfully unlabeled.
# File 2377.mat is successfully unlabeled.
# File 1656.mat is successfully unlabeled.
# File 1130.mat is successfully unlabeled.
# File 2439.mat is successfully unlabeled.
# File 1642.mat is successfully unlabeled.
# File 329.mat is successfully unlabeled.
# File 1695.mat is successfully unlabeled.
# File 301.mat is successfully unlabeled.
# File 467.mat is successfully unlabeled.
# File 473.mat is successfully unlabeled.
# File 2388.mat is successfully unlabeled.
# File 315.mat is successfully unlabeled.
# File 1681.mat is successfully unlabeled.
# File 1859.mat is successfully unlabeled.
# File 842.mat is successfully unlabeled.
# File 2161.mat is successfully unlabeled.
# File 1468.mat is successfully unlabeled.
# File 2175.mat is successfully unlabeled.
# File 16.mat is successfully unlabeled.
# File 1332.mat is successfully unlabeled.
# File 1454.mat is successfully unlabeled.
# File 1440.mat is successfully unlabeled.
# File 1326.mat is successfully unlabeled.
# File 659.mat is successfully unlabeled.
# File 881.mat is successfully unlabeled.
# File 895.mat is successfully unlabeled.
# File 2808.mat is successfully unlabeled.
# File 665.mat is successfully unlabeled.
# File 2820.mat is successfully unlabeled.
# File 103.mat is successfully unlabeled.
# File 1497.mat is successfully unlabeled.
# File 1483.mat is successfully unlabeled.
# File 117.mat is successfully unlabeled.
# File 2834.mat is successfully unlabeled.
# File 671.mat is successfully unlabeled.
# File 2773.mat is successfully unlabeled.
# File 1508.mat is successfully unlabeled.
# File 2001.mat is successfully unlabeled.
# File 2767.mat is successfully unlabeled.
# File 922.mat is successfully unlabeled.
# File 2997.mat is successfully unlabeled.
# File 1520.mat is successfully unlabeled.
# File 2029.mat is successfully unlabeled.
# File 1534.mat is successfully unlabeled.
# File 711.mat is successfully unlabeled.
# File 1285.mat is successfully unlabeled.
# File 2954.mat is successfully unlabeled.
# File 2940.mat is successfully unlabeled.
# File 705.mat is successfully unlabeled.
# File 2571.mat is successfully unlabeled.
# File 1078.mat is successfully unlabeled.
# File 2203.mat is successfully unlabeled.
# File 1722.mat is successfully unlabeled.
# File 1044.mat is successfully unlabeled.
# File 2559.mat is successfully unlabeled.
# File 1736.mat is successfully unlabeled.
# File 1905.mat is successfully unlabeled.
# File 249.mat is successfully unlabeled.
# File 1939.mat is successfully unlabeled.
# File 275.mat is successfully unlabeled.
# File 1087.mat is successfully unlabeled.
# File 513.mat is successfully unlabeled.
# File 507.mat is successfully unlabeled.
# File 1093.mat is successfully unlabeled.
# File 261.mat is successfully unlabeled.
# File 1962.mat is successfully unlabeled.
# File 548.mat is successfully unlabeled.
# File 560.mat is successfully unlabeled.
# File 206.mat is successfully unlabeled.
# File 212.mat is successfully unlabeled.
# File 1786.mat is successfully unlabeled.
# File 574.mat is successfully unlabeled.
# File 2502.mat is successfully unlabeled.
# File 2264.mat is successfully unlabeled.
# File 1779.mat is successfully unlabeled.
# File 2270.mat is successfully unlabeled.
# File 1037.mat is successfully unlabeled.
# File 1751.mat is successfully unlabeled.
# File 2258.mat is successfully unlabeled.
# File 1745.mat is successfully unlabeled.
# File 1023.mat is successfully unlabeled.
# File 986.mat is successfully unlabeled.
# File 992.mat is successfully unlabeled.
# File 1590.mat is successfully unlabeled.
# File 2099.mat is successfully unlabeled.
# File 2927.mat is successfully unlabeled.
# File 1584.mat is successfully unlabeled.
# File 2700.mat is successfully unlabeled.
# File 945.mat is successfully unlabeled.
# File 1209.mat is successfully unlabeled.
# File 789.mat is successfully unlabeled.
# File 1553.mat is successfully unlabeled.
# File 1235.mat is successfully unlabeled.
# File 1221.mat is successfully unlabeled.
# File 1547.mat is successfully unlabeled.
# File 158.mat is successfully unlabeled.
# File 170.mat is successfully unlabeled.
# File 616.mat is successfully unlabeled.
# File 1382.mat is successfully unlabeled.
# File 1396.mat is successfully unlabeled.
# File 602.mat is successfully unlabeled.
# File 2847.mat is successfully unlabeled.
# File 164.mat is successfully unlabeled.
# File 2674.mat is successfully unlabeled.
# File 71.mat is successfully unlabeled.
# File 831.mat is successfully unlabeled.
# File 1369.mat is successfully unlabeled.
# File 65.mat is successfully unlabeled.
# File 825.mat is successfully unlabeled.
# File 2106.mat is successfully unlabeled.
# File 1427.mat is successfully unlabeled.
# File 1341.mat is successfully unlabeled.
# File 2890.mat is successfully unlabeled.
# File 2648.mat is successfully unlabeled.
# File 1355.mat is successfully unlabeled.
# File 59.mat is successfully unlabeled.
# File 819.mat is successfully unlabeled.
# File 428.mat is successfully unlabeled.
# File 1802.mat is successfully unlabeled.
# File 1816.mat is successfully unlabeled.
# File 1180.mat is successfully unlabeled.
# File 414.mat is successfully unlabeled.
# File 372.mat is successfully unlabeled.
# File 366.mat is successfully unlabeled.
# File 400.mat is successfully unlabeled.
# File 2476.mat is successfully unlabeled.
# File 2310.mat is successfully unlabeled.
# File 1619.mat is successfully unlabeled.
# File 399.mat is successfully unlabeled.
# File 1143.mat is successfully unlabeled.
# File 1625.mat is successfully unlabeled.
# File 3032.mat is successfully unlabeled.
# File 2338.mat is successfully unlabeled.
# File 1157.mat is successfully unlabeled.
# File 1630.mat is successfully unlabeled.
# File 2339.mat is successfully unlabeled.
# File 1156.mat is successfully unlabeled.
# File 3033.mat is successfully unlabeled.
# File 1624.mat is successfully unlabeled.
# File 2305.mat is successfully unlabeled.
# File 398.mat is successfully unlabeled.
# File 2463.mat is successfully unlabeled.
# File 2477.mat is successfully unlabeled.
# File 2311.mat is successfully unlabeled.
# File 367.mat is successfully unlabeled.
# File 1195.mat is successfully unlabeled.
# File 401.mat is successfully unlabeled.
# File 415.mat is successfully unlabeled.
# File 1181.mat is successfully unlabeled.
# File 373.mat is successfully unlabeled.
# File 1817.mat is successfully unlabeled.
# File 429.mat is successfully unlabeled.
# File 1803.mat is successfully unlabeled.
# File 818.mat is successfully unlabeled.
# File 58.mat is successfully unlabeled.
# File 1354.mat is successfully unlabeled.
# File 2885.mat is successfully unlabeled.
# File 1432.mat is successfully unlabeled.
# File 1426.mat is successfully unlabeled.
# File 2649.mat is successfully unlabeled.
# File 1340.mat is successfully unlabeled.
# File 2661.mat is successfully unlabeled.
# File 64.mat is successfully unlabeled.
# File 1368.mat is successfully unlabeled.
# File 2107.mat is successfully unlabeled.
# File 70.mat is successfully unlabeled.
# File 2846.mat is successfully unlabeled.
# File 603.mat is successfully unlabeled.
# File 1397.mat is successfully unlabeled.
# File 165.mat is successfully unlabeled.
# File 171.mat is successfully unlabeled.
# File 1383.mat is successfully unlabeled.
# File 617.mat is successfully unlabeled.
# File 159.mat is successfully unlabeled.
# File 1220.mat is successfully unlabeled.
# File 2729.mat is successfully unlabeled.
# File 1552.mat is successfully unlabeled.
# File 1234.mat is successfully unlabeled.
# File 978.mat is successfully unlabeled.
# File 2715.mat is successfully unlabeled.
# File 788.mat is successfully unlabeled.
# File 950.mat is successfully unlabeled.
# File 1208.mat is successfully unlabeled.
# File 2701.mat is successfully unlabeled.
# File 2932.mat is successfully unlabeled.
# File 777.mat is successfully unlabeled.
# File 1585.mat is successfully unlabeled.
# File 2098.mat is successfully unlabeled.
# File 2926.mat is successfully unlabeled.
# File 993.mat is successfully unlabeled.
# File 987.mat is successfully unlabeled.
# File 1022.mat is successfully unlabeled.
# File 1036.mat is successfully unlabeled.
# File 2259.mat is successfully unlabeled.
# File 1750.mat is successfully unlabeled.
# File 1988.mat is successfully unlabeled.
# File 1778.mat is successfully unlabeled.
# File 2517.mat is successfully unlabeled.
# File 2265.mat is successfully unlabeled.
# File 213.mat is successfully unlabeled.
# File 575.mat is successfully unlabeled.
# File 561.mat is successfully unlabeled.
# File 207.mat is successfully unlabeled.
# File 549.mat is successfully unlabeled.
# File 1961.mat is successfully unlabeled.
# File 239.mat is successfully unlabeled.
# File 577.mat is successfully unlabeled.
# File 211.mat is successfully unlabeled.
# File 1791.mat is successfully unlabeled.
# File 205.mat is successfully unlabeled.
# File 1949.mat is successfully unlabeled.
# File 563.mat is successfully unlabeled.
# File 588.mat is successfully unlabeled.
# File 2273.mat is successfully unlabeled.
# File 1008.mat is successfully unlabeled.
# File 1020.mat is successfully unlabeled.
# File 2529.mat is successfully unlabeled.
# File 1746.mat is successfully unlabeled.
# File 1752.mat is successfully unlabeled.
# File 1034.mat is successfully unlabeled.
# File 985.mat is successfully unlabeled.
# File 1587.mat is successfully unlabeled.
# File 775.mat is successfully unlabeled.
# File 2930.mat is successfully unlabeled.
# File 761.mat is successfully unlabeled.
# File 1578.mat is successfully unlabeled.
# File 946.mat is successfully unlabeled.
# File 2065.mat is successfully unlabeled.
# File 1544.mat is successfully unlabeled.
# File 1222.mat is successfully unlabeled.
# File 1236.mat is successfully unlabeled.
# File 629.mat is successfully unlabeled.
# File 167.mat is successfully unlabeled.
# File 1395.mat is successfully unlabeled.
# File 601.mat is successfully unlabeled.
# File 99.mat is successfully unlabeled.
# File 2850.mat is successfully unlabeled.
# File 615.mat is successfully unlabeled.
# File 173.mat is successfully unlabeled.
# File 2105.mat is successfully unlabeled.
# File 198.mat is successfully unlabeled.
# File 66.mat is successfully unlabeled.
# File 826.mat is successfully unlabeled.
# File 72.mat is successfully unlabeled.
# File 832.mat is successfully unlabeled.
# File 1418.mat is successfully unlabeled.
# File 1430.mat is successfully unlabeled.
# File 8.mat is successfully unlabeled.
# File 1356.mat is successfully unlabeled.
# File 1342.mat is successfully unlabeled.
# File 1424.mat is successfully unlabeled.
# File 1815.mat is successfully unlabeled.
# File 359.mat is successfully unlabeled.
# File 403.mat is successfully unlabeled.
# File 1197.mat is successfully unlabeled.
# File 365.mat is successfully unlabeled.
# File 371.mat is successfully unlabeled.
# File 417.mat is successfully unlabeled.
# File 2461.mat is successfully unlabeled.
# File 2475.mat is successfully unlabeled.
# File 3025.mat is successfully unlabeled.
# File 1626.mat is successfully unlabeled.
# File 3031.mat is successfully unlabeled.
# File 2449.mat is successfully unlabeled.
# File 1140.mat is successfully unlabeled.
# File 3030.mat is successfully unlabeled.
# File 1627.mat is successfully unlabeled.
# File 1141.mat is successfully unlabeled.
# File 1155.mat is successfully unlabeled.
# File 1633.mat is successfully unlabeled.
# File 2312.mat is successfully unlabeled.
# File 2474.mat is successfully unlabeled.
# File 3018.mat is successfully unlabeled.
# File 370.mat is successfully unlabeled.
# File 416.mat is successfully unlabeled.
# File 1182.mat is successfully unlabeled.
# File 1196.mat is successfully unlabeled.
# File 402.mat is successfully unlabeled.
# File 364.mat is successfully unlabeled.
# File 1828.mat is successfully unlabeled.
# File 1800.mat is successfully unlabeled.
# File 358.mat is successfully unlabeled.
# File 1814.mat is successfully unlabeled.
# File 1343.mat is successfully unlabeled.
# File 9.mat is successfully unlabeled.
# File 2138.mat is successfully unlabeled.
# File 1431.mat is successfully unlabeled.
# File 1357.mat is successfully unlabeled.
# File 833.mat is successfully unlabeled.
# File 73.mat is successfully unlabeled.
# File 2110.mat is successfully unlabeled.
# File 1419.mat is successfully unlabeled.
# File 199.mat is successfully unlabeled.
# File 827.mat is successfully unlabeled.
# File 67.mat is successfully unlabeled.
# File 1380.mat is successfully unlabeled.
# File 614.mat is successfully unlabeled.
# File 2851.mat is successfully unlabeled.
# File 172.mat is successfully unlabeled.
# File 166.mat is successfully unlabeled.
# File 2845.mat is successfully unlabeled.
# File 98.mat is successfully unlabeled.
# File 600.mat is successfully unlabeled.
# File 1394.mat is successfully unlabeled.
# File 628.mat is successfully unlabeled.
# File 2879.mat is successfully unlabeled.
# File 1237.mat is successfully unlabeled.
# File 2058.mat is successfully unlabeled.
# File 1545.mat is successfully unlabeled.
# File 2064.mat is successfully unlabeled.
# File 1579.mat is successfully unlabeled.
# File 2070.mat is successfully unlabeled.
# File 2716.mat is successfully unlabeled.
# File 1592.mat is successfully unlabeled.
# File 1586.mat is successfully unlabeled.
# File 774.mat is successfully unlabeled.
# File 984.mat is successfully unlabeled.
# File 990.mat is successfully unlabeled.
# File 748.mat is successfully unlabeled.
# File 1753.mat is successfully unlabeled.
# File 1035.mat is successfully unlabeled.
# File 2528.mat is successfully unlabeled.
# File 1021.mat is successfully unlabeled.
# File 1747.mat is successfully unlabeled.
# File 1009.mat is successfully unlabeled.
# File 589.mat is successfully unlabeled.
# File 2272.mat is successfully unlabeled.
# File 204.mat is successfully unlabeled.
# File 2299.mat is successfully unlabeled.
# File 562.mat is successfully unlabeled.
# File 576.mat is successfully unlabeled.
# File 1784.mat is successfully unlabeled.
# File 1974.mat is successfully unlabeled.
# File 238.mat is successfully unlabeled.
# File 1960.mat is successfully unlabeled.
# File 214.mat is successfully unlabeled.
# File 1780.mat is successfully unlabeled.
# File 1958.mat is successfully unlabeled.
# File 2289.mat is successfully unlabeled.
# File 572.mat is successfully unlabeled.
# File 566.mat is successfully unlabeled.
# File 1794.mat is successfully unlabeled.
# File 200.mat is successfully unlabeled.
# File 228.mat is successfully unlabeled.
# File 1743.mat is successfully unlabeled.
# File 1025.mat is successfully unlabeled.
# File 1031.mat is successfully unlabeled.
# File 1019.mat is successfully unlabeled.
# File 599.mat is successfully unlabeled.
# File 2262.mat is successfully unlabeled.
# File 2935.mat is successfully unlabeled.
# File 1582.mat is successfully unlabeled.
# File 994.mat is successfully unlabeled.
# File 758.mat is successfully unlabeled.
# File 1227.mat is successfully unlabeled.
# File 1555.mat is successfully unlabeled.
# File 957.mat is successfully unlabeled.
# File 1569.mat is successfully unlabeled.
# File 2060.mat is successfully unlabeled.
# File 2706.mat is successfully unlabeled.
# File 943.mat is successfully unlabeled.
# File 1390.mat is successfully unlabeled.
# File 604.mat is successfully unlabeled.
# File 162.mat is successfully unlabeled.
# File 176.mat is successfully unlabeled.
# File 88.mat is successfully unlabeled.
# File 610.mat is successfully unlabeled.
# File 1384.mat is successfully unlabeled.
# File 638.mat is successfully unlabeled.
# File 2869.mat is successfully unlabeled.
# File 2882.mat is successfully unlabeled.
# File 1353.mat is successfully unlabeled.
# File 1435.mat is successfully unlabeled.
# File 1421.mat is successfully unlabeled.
# File 63.mat is successfully unlabeled.
# File 2666.mat is successfully unlabeled.
# File 1409.mat is successfully unlabeled.
# File 189.mat is successfully unlabeled.
# File 2114.mat is successfully unlabeled.
# File 2672.mat is successfully unlabeled.
# File 77.mat is successfully unlabeled.
# File 360.mat is successfully unlabeled.
# File 406.mat is successfully unlabeled.
# File 1192.mat is successfully unlabeled.
# File 1186.mat is successfully unlabeled.
# File 412.mat is successfully unlabeled.
# File 1838.mat is successfully unlabeled.
# File 374.mat is successfully unlabeled.
# File 1810.mat is successfully unlabeled.
# File 1804.mat is successfully unlabeled.
# File 348.mat is successfully unlabeled.
# File 1637.mat is successfully unlabeled.
# File 1623.mat is successfully unlabeled.
# File 3034.mat is successfully unlabeled.
# File 1179.mat is successfully unlabeled.
# File 2316.mat is successfully unlabeled.
# File 1178.mat is successfully unlabeled.
# File 3009.mat is successfully unlabeled.
# File 2465.mat is successfully unlabeled.
# File 1144.mat is successfully unlabeled.
# File 1622.mat is successfully unlabeled.
# File 1636.mat is successfully unlabeled.
# File 1150.mat is successfully unlabeled.
# File 349.mat is successfully unlabeled.
# File 1805.mat is successfully unlabeled.
# File 1811.mat is successfully unlabeled.
# File 413.mat is successfully unlabeled.
# File 1187.mat is successfully unlabeled.
# File 375.mat is successfully unlabeled.
# File 361.mat is successfully unlabeled.
# File 407.mat is successfully unlabeled.
# File 188.mat is successfully unlabeled.
# File 76.mat is successfully unlabeled.
# File 62.mat is successfully unlabeled.
# File 1408.mat is successfully unlabeled.
# File 2101.mat is successfully unlabeled.
# File 1420.mat is successfully unlabeled.
# File 2129.mat is successfully unlabeled.
# File 1346.mat is successfully unlabeled.
# File 1352.mat is successfully unlabeled.
# File 1434.mat is successfully unlabeled.
# File 2868.mat is successfully unlabeled.
# File 639.mat is successfully unlabeled.
# File 177.mat is successfully unlabeled.
# File 1385.mat is successfully unlabeled.
# File 611.mat is successfully unlabeled.
# File 89.mat is successfully unlabeled.
# File 2840.mat is successfully unlabeled.
# File 605.mat is successfully unlabeled.
# File 1391.mat is successfully unlabeled.
# File 163.mat is successfully unlabeled.
# File 1568.mat is successfully unlabeled.
# File 942.mat is successfully unlabeled.
# File 2713.mat is successfully unlabeled.
# File 956.mat is successfully unlabeled.
# File 1554.mat is successfully unlabeled.
# File 1232.mat is successfully unlabeled.
# File 1226.mat is successfully unlabeled.
# File 1540.mat is successfully unlabeled.
# File 981.mat is successfully unlabeled.
# File 759.mat is successfully unlabeled.
# File 995.mat is successfully unlabeled.
# File 1597.mat is successfully unlabeled.
# File 765.mat is successfully unlabeled.
# File 2920.mat is successfully unlabeled.
# File 2505.mat is successfully unlabeled.
# File 598.mat is successfully unlabeled.
# File 2263.mat is successfully unlabeled.
# File 2277.mat is successfully unlabeled.
# File 1030.mat is successfully unlabeled.
# File 2539.mat is successfully unlabeled.
# File 1756.mat is successfully unlabeled.
# File 1742.mat is successfully unlabeled.
# File 1024.mat is successfully unlabeled.
# File 1965.mat is successfully unlabeled.
# File 229.mat is successfully unlabeled.
# File 567.mat is successfully unlabeled.
# File 201.mat is successfully unlabeled.
# File 1795.mat is successfully unlabeled.
# File 1781.mat is successfully unlabeled.
# File 215.mat is successfully unlabeled.
# File 573.mat is successfully unlabeled.
# File 1797.mat is successfully unlabeled.
# File 203.mat is successfully unlabeled.
# File 565.mat is successfully unlabeled.
# File 571.mat is successfully unlabeled.
# File 217.mat is successfully unlabeled.
# File 1783.mat is successfully unlabeled.
# File 559.mat is successfully unlabeled.
# File 1754.mat is successfully unlabeled.
# File 1026.mat is successfully unlabeled.
# File 1998.mat is successfully unlabeled.
# File 1740.mat is successfully unlabeled.
# File 1768.mat is successfully unlabeled.
# File 2507.mat is successfully unlabeled.
# File 2513.mat is successfully unlabeled.
# File 767.mat is successfully unlabeled.
# File 1595.mat is successfully unlabeled.
# File 2088.mat is successfully unlabeled.
# File 1581.mat is successfully unlabeled.
# File 773.mat is successfully unlabeled.
# File 1230.mat is successfully unlabeled.
# File 1556.mat is successfully unlabeled.
# File 1542.mat is successfully unlabeled.
# File 968.mat is successfully unlabeled.
# File 1224.mat is successfully unlabeled.
# File 940.mat is successfully unlabeled.
# File 798.mat is successfully unlabeled.
# File 2063.mat is successfully unlabeled.
# File 2077.mat is successfully unlabeled.
# File 954.mat is successfully unlabeled.
# File 1218.mat is successfully unlabeled.
# File 2711.mat is successfully unlabeled.
# File 2856.mat is successfully unlabeled.
# File 613.mat is successfully unlabeled.
# File 1387.mat is successfully unlabeled.
# File 175.mat is successfully unlabeled.
# File 161.mat is successfully unlabeled.
# File 1393.mat is successfully unlabeled.
# File 607.mat is successfully unlabeled.
# File 149.mat is successfully unlabeled.
# File 48.mat is successfully unlabeled.
# File 1344.mat is successfully unlabeled.
# File 808.mat is successfully unlabeled.
# File 1436.mat is successfully unlabeled.
# File 1350.mat is successfully unlabeled.
# File 2671.mat is successfully unlabeled.
# File 74.mat is successfully unlabeled.
# File 1378.mat is successfully unlabeled.
# File 60.mat is successfully unlabeled.
# File 820.mat is successfully unlabeled.
# File 2665.mat is successfully unlabeled.
# File 377.mat is successfully unlabeled.
# File 1185.mat is successfully unlabeled.
# File 411.mat is successfully unlabeled.
# File 405.mat is successfully unlabeled.
# File 1191.mat is successfully unlabeled.
# File 363.mat is successfully unlabeled.
# File 439.mat is successfully unlabeled.
# File 1620.mat is successfully unlabeled.
# File 3037.mat is successfully unlabeled.
# File 1146.mat is successfully unlabeled.
# File 1152.mat is successfully unlabeled.
# File 3023.mat is successfully unlabeled.
# File 2315.mat is successfully unlabeled.
# File 388.mat is successfully unlabeled.
# File 2473.mat is successfully unlabeled.
# File 1608.mat is successfully unlabeled.
# File 2300.mat is successfully unlabeled.
# File 1609.mat is successfully unlabeled.
# File 389.mat is successfully unlabeled.
# File 2314.mat is successfully unlabeled.
# File 1153.mat is successfully unlabeled.
# File 1635.mat is successfully unlabeled.
# File 3022.mat is successfully unlabeled.
# File 3036.mat is successfully unlabeled.
# File 1621.mat is successfully unlabeled.
# File 1147.mat is successfully unlabeled.
# File 438.mat is successfully unlabeled.
# File 1812.mat is successfully unlabeled.
# File 1806.mat is successfully unlabeled.
# File 1190.mat is successfully unlabeled.
# File 404.mat is successfully unlabeled.
# File 2499.mat is successfully unlabeled.
# File 362.mat is successfully unlabeled.
# File 376.mat is successfully unlabeled.
# File 410.mat is successfully unlabeled.
# File 1184.mat is successfully unlabeled.
# File 2102.mat is successfully unlabeled.
# File 2664.mat is successfully unlabeled.
# File 821.mat is successfully unlabeled.
# File 61.mat is successfully unlabeled.
# File 835.mat is successfully unlabeled.
# File 1379.mat is successfully unlabeled.
# File 75.mat is successfully unlabeled.
# File 2670.mat is successfully unlabeled.
# File 2116.mat is successfully unlabeled.
# File 1437.mat is successfully unlabeled.
# File 1351.mat is successfully unlabeled.
# File 2658.mat is successfully unlabeled.
# File 2880.mat is successfully unlabeled.
# File 809.mat is successfully unlabeled.
# File 49.mat is successfully unlabeled.
# File 1423.mat is successfully unlabeled.
# File 148.mat is successfully unlabeled.
# File 160.mat is successfully unlabeled.
# File 2843.mat is successfully unlabeled.
# File 606.mat is successfully unlabeled.
# File 1392.mat is successfully unlabeled.
# File 612.mat is successfully unlabeled.
# File 2857.mat is successfully unlabeled.
# File 174.mat is successfully unlabeled.
# File 1219.mat is successfully unlabeled.
# File 799.mat is successfully unlabeled.
# File 941.mat is successfully unlabeled.
# File 1225.mat is successfully unlabeled.
# File 2738.mat is successfully unlabeled.
# File 1231.mat is successfully unlabeled.
# File 996.mat is successfully unlabeled.
# File 982.mat is successfully unlabeled.
# File 1580.mat is successfully unlabeled.
# File 766.mat is successfully unlabeled.
# File 2923.mat is successfully unlabeled.
# File 1594.mat is successfully unlabeled.
# File 2260.mat is successfully unlabeled.
# File 2506.mat is successfully unlabeled.
# File 1999.mat is successfully unlabeled.
# File 2248.mat is successfully unlabeled.
# File 1755.mat is successfully unlabeled.
# File 1033.mat is successfully unlabeled.
# File 558.mat is successfully unlabeled.
# File 570.mat is successfully unlabeled.
# File 1782.mat is successfully unlabeled.
# File 216.mat is successfully unlabeled.
# File 202.mat is successfully unlabeled.
# File 564.mat is successfully unlabeled.
# File 2292.mat is successfully unlabeled.
# File 569.mat is successfully unlabeled.
# File 541.mat is successfully unlabeled.
# File 227.mat is successfully unlabeled.
# File 233.mat is successfully unlabeled.
# File 555.mat is successfully unlabeled.
# File 2523.mat is successfully unlabeled.
# File 2245.mat is successfully unlabeled.
# File 1980.mat is successfully unlabeled.
# File 1758.mat is successfully unlabeled.
# File 582.mat is successfully unlabeled.
# File 1016.mat is successfully unlabeled.
# File 2279.mat is successfully unlabeled.
# File 1770.mat is successfully unlabeled.
# File 1002.mat is successfully unlabeled.
# File 596.mat is successfully unlabeled.
# File 1599.mat is successfully unlabeled.
# File 743.mat is successfully unlabeled.
# File 2906.mat is successfully unlabeled.
# File 757.mat is successfully unlabeled.
# File 2047.mat is successfully unlabeled.
# File 1228.mat is successfully unlabeled.
# File 2721.mat is successfully unlabeled.
# File 970.mat is successfully unlabeled.
# File 2053.mat is successfully unlabeled.
# File 1572.mat is successfully unlabeled.
# File 958.mat is successfully unlabeled.
# File 1214.mat is successfully unlabeled.
# File 1566.mat is successfully unlabeled.
# File 93.mat is successfully unlabeled.
# File 87.mat is successfully unlabeled.
# File 179.mat is successfully unlabeled.
# File 151.mat is successfully unlabeled.
# File 637.mat is successfully unlabeled.
# File 623.mat is successfully unlabeled.
# File 145.mat is successfully unlabeled.
# File 2133.mat is successfully unlabeled.
# File 2.mat is successfully unlabeled.
# File 50.mat is successfully unlabeled.
# File 2655.mat is successfully unlabeled.
# File 2899.mat is successfully unlabeled.
# File 2641.mat is successfully unlabeled.
# File 1348.mat is successfully unlabeled.
# File 44.mat is successfully unlabeled.
# File 804.mat is successfully unlabeled.
# File 192.mat is successfully unlabeled.
# File 2669.mat is successfully unlabeled.
# File 1360.mat is successfully unlabeled.
# File 1374.mat is successfully unlabeled.
# File 78.mat is successfully unlabeled.
# File 838.mat is successfully unlabeled.
# File 186.mat is successfully unlabeled.
# File 1412.mat is successfully unlabeled.
# File 409.mat is successfully unlabeled.
# File 1823.mat is successfully unlabeled.
# File 2480.mat is successfully unlabeled.
# File 1189.mat is successfully unlabeled.
# File 435.mat is successfully unlabeled.
# File 353.mat is successfully unlabeled.
# File 347.mat is successfully unlabeled.
# File 421.mat is successfully unlabeled.
# File 2331.mat is successfully unlabeled.
# File 1162.mat is successfully unlabeled.
# File 390.mat is successfully unlabeled.
# File 1604.mat is successfully unlabeled.
# File 384.mat is successfully unlabeled.
# File 3007.mat is successfully unlabeled.
# File 1176.mat is successfully unlabeled.
# File 2318.mat is successfully unlabeled.
# File 3006.mat is successfully unlabeled.
# File 385.mat is successfully unlabeled.
# File 1611.mat is successfully unlabeled.
# File 1163.mat is successfully unlabeled.
# File 1605.mat is successfully unlabeled.
# File 391.mat is successfully unlabeled.
# File 2330.mat is successfully unlabeled.
# File 346.mat is successfully unlabeled.
# File 420.mat is successfully unlabeled.
# File 434.mat is successfully unlabeled.
# File 352.mat is successfully unlabeled.
# File 1836.mat is successfully unlabeled.
# File 1188.mat is successfully unlabeled.
# File 2481.mat is successfully unlabeled.
# File 408.mat is successfully unlabeled.
# File 1822.mat is successfully unlabeled.
# File 839.mat is successfully unlabeled.
# File 79.mat is successfully unlabeled.
# File 1375.mat is successfully unlabeled.
# File 1413.mat is successfully unlabeled.
# File 187.mat is successfully unlabeled.
# File 193.mat is successfully unlabeled.
# File 1361.mat is successfully unlabeled.
# File 805.mat is successfully unlabeled.
# File 45.mat is successfully unlabeled.
# File 1349.mat is successfully unlabeled.
# File 2640.mat is successfully unlabeled.
# File 2898.mat is successfully unlabeled.
# File 3.mat is successfully unlabeled.
# File 2654.mat is successfully unlabeled.
# File 811.mat is successfully unlabeled.
# File 51.mat is successfully unlabeled.
# File 622.mat is successfully unlabeled.
# File 144.mat is successfully unlabeled.
# File 150.mat is successfully unlabeled.
# File 2873.mat is successfully unlabeled.
# File 636.mat is successfully unlabeled.
# File 86.mat is successfully unlabeled.
# File 178.mat is successfully unlabeled.
# File 92.mat is successfully unlabeled.
# File 2697.mat is successfully unlabeled.
# File 795.mat is successfully unlabeled.
# File 1567.mat is successfully unlabeled.
# File 1215.mat is successfully unlabeled.
# File 959.mat is successfully unlabeled.
# File 971.mat is successfully unlabeled.
# File 2052.mat is successfully unlabeled.
# File 2046.mat is successfully unlabeled.
# File 1229.mat is successfully unlabeled.
# File 2913.mat is successfully unlabeled.
# File 2907.mat is successfully unlabeled.
# File 1598.mat is successfully unlabeled.
# File 2091.mat is successfully unlabeled.
# File 2085.mat is successfully unlabeled.
# File 597.mat is successfully unlabeled.
# File 1003.mat is successfully unlabeled.
# File 1017.mat is successfully unlabeled.
# File 583.mat is successfully unlabeled.
# File 1771.mat is successfully unlabeled.
# File 1759.mat is successfully unlabeled.
# File 1981.mat is successfully unlabeled.
# File 2250.mat is successfully unlabeled.
# File 2522.mat is successfully unlabeled.
# File 2244.mat is successfully unlabeled.
# File 1995.mat is successfully unlabeled.
# File 232.mat is successfully unlabeled.
# File 554.mat is successfully unlabeled.
# File 540.mat is successfully unlabeled.
# File 226.mat is successfully unlabeled.
# File 568.mat is successfully unlabeled.
# File 1798.mat is successfully unlabeled.
# File 2291.mat is successfully unlabeled.
# File 2285.mat is successfully unlabeled.
# File 218.mat is successfully unlabeled.
# File 556.mat is successfully unlabeled.
# File 230.mat is successfully unlabeled.
# File 224.mat is successfully unlabeled.
# File 1968.mat is successfully unlabeled.
# ...
# File 251.mat is successfully unlabeled.
# File 245.mat is successfully unlabeled.
# File 523.mat is successfully unlabeled.
# File 2596.mat is successfully unlabeled.
# File 1921.mat is successfully unlabeled.
# File 1935.mat is successfully unlabeled.
# File 279.mat is successfully unlabeled.
# File 2582.mat is successfully unlabeled.
# File 509.mat is successfully unlabeled.
# File 1089.mat is successfully unlabeled.
# File 253.mat is successfully unlabeled.
# File 535.mat is successfully unlabeled.
# File 521.mat is successfully unlabeled.
# File 247.mat is successfully unlabeled.
# File 2231.mat is successfully unlabeled.
# File 290.mat is successfully unlabeled.
# File 1062.mat is successfully unlabeled.
# File 284.mat is successfully unlabeled.
# File 1710.mat is successfully unlabeled.
# File 723.mat is successfully unlabeled.
# File 910.mat is successfully unlabeled.
# File 2741.mat is successfully unlabeled.
# File 904.mat is successfully unlabeled.
# File 1248.mat is successfully unlabeled.
# File 2769.mat is successfully unlabeled.
# File 1260.mat is successfully unlabeled.
# File 1512.mat is successfully unlabeled.
# File 938.mat is successfully unlabeled.
# File 1274.mat is successfully unlabeled.
# File 119.mat is successfully unlabeled.
# File 643.mat is successfully unlabeled.
# File 2806.mat is successfully unlabeled.
# File 125.mat is successfully unlabeled.
# File 131.mat is successfully unlabeled.
# File 2812.mat is successfully unlabeled.
# File 657.mat is successfully unlabeled.
# File 1328.mat is successfully unlabeled.
# File 24.mat is successfully unlabeled.
# File 864.mat is successfully unlabeled.
# File 2147.mat is successfully unlabeled.
# File 2153.mat is successfully unlabeled.
# File 30.mat is successfully unlabeled.
# File 870.mat is successfully unlabeled.
# File 680.mat is successfully unlabeled.
# File 1314.mat is successfully unlabeled.
# File 18.mat is successfully unlabeled.
# File 858.mat is successfully unlabeled.
# File 1472.mat is successfully unlabeled.
# File 1466.mat is successfully unlabeled.
# File 1300.mat is successfully unlabeled.
# File 694.mat is successfully unlabeled.
# File 2609.mat is successfully unlabeled.
# File 1857.mat is successfully unlabeled.
# File 469.mat is successfully unlabeled.
# File 2392.mat is successfully unlabeled.
# File 327.mat is successfully unlabeled.
# File 441.mat is successfully unlabeled.
# File 455.mat is successfully unlabeled.
# File 333.mat is successfully unlabeled.
# File 2345.mat is successfully unlabeled.
# File 2423.mat is successfully unlabeled.
# File 1658.mat is successfully unlabeled.
# File 1880.mat is successfully unlabeled.
# File 1116.mat is successfully unlabeled.
# File 482.mat is successfully unlabeled.
# File 496.mat is successfully unlabeled.
# File 1102.mat is successfully unlabeled.
# File 1664.mat is successfully unlabeled.
# File 1103.mat is successfully unlabeled.
# File 497.mat is successfully unlabeled.
# File 1665.mat is successfully unlabeled.
# File 2378.mat is successfully unlabeled.
# File 483.mat is successfully unlabeled.
# File 1117.mat is successfully unlabeled.
# File 2350.mat is successfully unlabeled.
# File 454.mat is successfully unlabeled.
# File 332.mat is successfully unlabeled.
# File 326.mat is successfully unlabeled.
# File 440.mat is successfully unlabeled.
# File 468.mat is successfully unlabeled.
# File 2393.mat is successfully unlabeled.
# File 1856.mat is successfully unlabeled.
# File 1467.mat is successfully unlabeled.
# File 2608.mat is successfully unlabeled.
# File 695.mat is successfully unlabeled.
# File 1301.mat is successfully unlabeled.
# File 859.mat is successfully unlabeled.
# File 19.mat is successfully unlabeled.
# File 681.mat is successfully unlabeled.
# File 2152.mat is successfully unlabeled.
# File 31.mat is successfully unlabeled.
# File 2634.mat is successfully unlabeled.
# File 25.mat is successfully unlabeled.
# File 130.mat is successfully unlabeled.
# File 656.mat is successfully unlabeled.
# File 642.mat is successfully unlabeled.
# File 124.mat is successfully unlabeled.
# File 1498.mat is successfully unlabeled.
# File 2191.mat is successfully unlabeled.
# File 118.mat is successfully unlabeled.
# File 1513.mat is successfully unlabeled.
# File 1275.mat is successfully unlabeled.
# File 939.mat is successfully unlabeled.
# File 1261.mat is successfully unlabeled.
# File 2768.mat is successfully unlabeled.
# File 905.mat is successfully unlabeled.
# File 2998.mat is successfully unlabeled.
# File 2754.mat is successfully unlabeled.
# File 911.mat is successfully unlabeled.
# File 2032.mat is successfully unlabeled.
# File 2967.mat is successfully unlabeled.
# File 736.mat is successfully unlabeled.
# File 2797.mat is successfully unlabeled.
# File 1077.mat is successfully unlabeled.
# File 2218.mat is successfully unlabeled.
# File 285.mat is successfully unlabeled.
# File 291.mat is successfully unlabeled.
# File 1705.mat is successfully unlabeled.
# File 1063.mat is successfully unlabeled.
# File 2542.mat is successfully unlabeled.
# File 2224.mat is successfully unlabeled.
# File 2230.mat is successfully unlabeled.
# File 1739.mat is successfully unlabeled.
# File 520.mat is successfully unlabeled.
# File 246.mat is successfully unlabeled.
# File 252.mat is successfully unlabeled.
# File 534.mat is successfully unlabeled.
# File 1088.mat is successfully unlabeled.
# File 2581.mat is successfully unlabeled.
# File 1922.mat is successfully unlabeled.
# File 508.mat is successfully unlabeled.
# File 530.mat is successfully unlabeled.
# File 256.mat is successfully unlabeled.
# File 242.mat is successfully unlabeled.
# File 524.mat is successfully unlabeled.
# File 2591.mat is successfully unlabeled.
# File 2585.mat is successfully unlabeled.
# File 518.mat is successfully unlabeled.
# File 2208.mat is successfully unlabeled.
# File 1701.mat is successfully unlabeled.
# File 295.mat is successfully unlabeled.
# File 281.mat is successfully unlabeled.
# File 1073.mat is successfully unlabeled.
# File 2220.mat is successfully unlabeled.
# File 2977.mat is successfully unlabeled.
# File 2787.mat is successfully unlabeled.
# File 929.mat is successfully unlabeled.
# File 2778.mat is successfully unlabeled.
# File 1517.mat is successfully unlabeled.
# File 2036.mat is successfully unlabeled.
# File 1259.mat is successfully unlabeled.
# File 2750.mat is successfully unlabeled.
# File 2744.mat is successfully unlabeled.
# File 901.mat is successfully unlabeled.
# File 2022.mat is successfully unlabeled.
# File 120.mat is successfully unlabeled.
# File 646.mat is successfully unlabeled.
# File 2817.mat is successfully unlabeled.
# File 652.mat is successfully unlabeled.
# File 134.mat is successfully unlabeled.
# File 1488.mat is successfully unlabeled.
# File 2195.mat is successfully unlabeled.
# File 108.mat is successfully unlabeled.
# File 1477.mat is successfully unlabeled.
# File 685.mat is successfully unlabeled.
# File 1311.mat is successfully unlabeled.
# File 691.mat is successfully unlabeled.
# File 849.mat is successfully unlabeled.
# File 1463.mat is successfully unlabeled.
# File 2142.mat is successfully unlabeled.
# File 21.mat is successfully unlabeled.
# File 861.mat is successfully unlabeled.
# File 2630.mat is successfully unlabeled.
# File 35.mat is successfully unlabeled.
# File 444.mat is successfully unlabeled.
# File 322.mat is successfully unlabeled.
# File 336.mat is successfully unlabeled.
# File 450.mat is successfully unlabeled.
# File 478.mat is successfully unlabeled.
# File 1846.mat is successfully unlabeled.
# File 487.mat is successfully unlabeled.
# File 3062.mat is successfully unlabeled.
# File 1675.mat is successfully unlabeled.
# File 1661.mat is successfully unlabeled.
# File 2368.mat is successfully unlabeled.
# File 493.mat is successfully unlabeled.
# File 1107.mat is successfully unlabeled.
# File 2426.mat is successfully unlabeled.
# File 1649.mat is successfully unlabeled.
# File 2340.mat is successfully unlabeled.
# File 2354.mat is successfully unlabeled.
# File 1885.mat is successfully unlabeled.
# File 2432.mat is successfully unlabeled.
# File 2355.mat is successfully unlabeled.
# File 1648.mat is successfully unlabeled.
# File 2369.mat is successfully unlabeled.
# File 1660.mat is successfully unlabeled.
# File 1106.mat is successfully unlabeled.
# File 492.mat is successfully unlabeled.
# File 486.mat is successfully unlabeled.
# File 3063.mat is successfully unlabeled.
# File 2396.mat is successfully unlabeled.
# File 1847.mat is successfully unlabeled.
# File 479.mat is successfully unlabeled.
# File 1853.mat is successfully unlabeled.
# File 2382.mat is successfully unlabeled.
# File 337.mat is successfully unlabeled.
# File 451.mat is successfully unlabeled.
# File 445.mat is successfully unlabeled.
# File 323.mat is successfully unlabeled.
# File 874.mat is successfully unlabeled.
# File 1338.mat is successfully unlabeled.
# File 34.mat is successfully unlabeled.
# File 2631.mat is successfully unlabeled.
# File 2143.mat is successfully unlabeled.
# File 2625.mat is successfully unlabeled.
# File 860.mat is successfully unlabeled.
# File 20.mat is successfully unlabeled.
# File 690.mat is successfully unlabeled.
# File 1304.mat is successfully unlabeled.
# File 1462.mat is successfully unlabeled.
# File 1476.mat is successfully unlabeled.
# File 1310.mat is successfully unlabeled.
# File 684.mat is successfully unlabeled.
# File 2619.mat is successfully unlabeled.
# File 109.mat is successfully unlabeled.
# File 2194.mat is successfully unlabeled.
# File 1489.mat is successfully unlabeled.
# File 653.mat is successfully unlabeled.
# File 2816.mat is successfully unlabeled.
# File 135.mat is successfully unlabeled.
# File 121.mat is successfully unlabeled.
# File 2802.mat is successfully unlabeled.
# File 647.mat is successfully unlabeled.
# File 900.mat is successfully unlabeled.
# File 2037.mat is successfully unlabeled.
# File 2751.mat is successfully unlabeled.
# File 914.mat is successfully unlabeled.
# File 2779.mat is successfully unlabeled.
# File 1270.mat is successfully unlabeled.
# File 1516.mat is successfully unlabeled.
# File 1502.mat is successfully unlabeled.
# File 1264.mat is successfully unlabeled.
# File 928.mat is successfully unlabeled.
# File 2786.mat is successfully unlabeled.
# File 2792.mat is successfully unlabeled.
# File 2976.mat is successfully unlabeled.
# File 733.mat is successfully unlabeled.
# File 1728.mat is successfully unlabeled.
# File 2221.mat is successfully unlabeled.
# File 2553.mat is successfully unlabeled.
# File 2235.mat is successfully unlabeled.
# File 1714.mat is successfully unlabeled.
# File 280.mat is successfully unlabeled.
# File 1066.mat is successfully unlabeled.
# File 294.mat is successfully unlabeled.
# File 2209.mat is successfully unlabeled.
# File 1933.mat is successfully unlabeled.
# File 519.mat is successfully unlabeled.
# File 1099.mat is successfully unlabeled.
# File 243.mat is successfully unlabeled.
# File 525.mat is successfully unlabeled.
# File 531.mat is successfully unlabeled.
# File 257.mat is successfully unlabeled.
# File 527.mat is successfully unlabeled.
# File 241.mat is successfully unlabeled.
# File 255.mat is successfully unlabeled.
# File 533.mat is successfully unlabeled.
# File 1931.mat is successfully unlabeled.
# File 269.mat is successfully unlabeled.
# File 2579.mat is successfully unlabeled.
# File 1070.mat is successfully unlabeled.
# File 282.mat is successfully unlabeled.
# File 1716.mat is successfully unlabeled.
# File 1702.mat is successfully unlabeled.
# File 296.mat is successfully unlabeled.
# File 1064.mat is successfully unlabeled.
# File 2223.mat is successfully unlabeled.
# File 2551.mat is successfully unlabeled.
# File 1058.mat is successfully unlabeled.
# File 2960.mat is successfully unlabeled.
# File 725.mat is successfully unlabeled.
# File 719.mat is successfully unlabeled.
# File 2790.mat is successfully unlabeled.
# File 1299.mat is successfully unlabeled.
# File 1514.mat is successfully unlabeled.
# File 1266.mat is successfully unlabeled.
# File 1500.mat is successfully unlabeled.
# File 1528.mat is successfully unlabeled.
# File 902.mat is successfully unlabeled.
# File 137.mat is successfully unlabeled.
# File 651.mat is successfully unlabeled.
# File 645.mat is successfully unlabeled.
# File 123.mat is successfully unlabeled.
# File 679.mat is successfully unlabeled.
# File 2182.mat is successfully unlabeled.
# File 1460.mat is successfully unlabeled.
# File 1306.mat is successfully unlabeled.
# File 692.mat is successfully unlabeled.
# File 686.mat is successfully unlabeled.
# File 1312.mat is successfully unlabeled.
# File 1474.mat is successfully unlabeled.
# File 2155.mat is successfully unlabeled.
# File 36.mat is successfully unlabeled.
# File 876.mat is successfully unlabeled.
# File 22.mat is successfully unlabeled.
# File 1448.mat is successfully unlabeled.
# File 453.mat is successfully unlabeled.
# File 1879.mat is successfully unlabeled.
# File 335.mat is successfully unlabeled.
# File 321.mat is successfully unlabeled.
# File 447.mat is successfully unlabeled.
# File 1845.mat is successfully unlabeled.
# File 309.mat is successfully unlabeled.
# File 2394.mat is successfully unlabeled.
# File 2380.mat is successfully unlabeled.
# File 490.mat is successfully unlabeled.
# File 1104.mat is successfully unlabeled.
# File 1110.mat is successfully unlabeled.
# File 484.mat is successfully unlabeled.
# File 1138.mat is successfully unlabeled.
# File 2431.mat is successfully unlabeled.
# File 3049.mat is successfully unlabeled.
# File 1892.mat is successfully unlabeled.
# File 2343.mat is successfully unlabeled.
# File 2342.mat is successfully unlabeled.
# File 1893.mat is successfully unlabeled.
# File 2424.mat is successfully unlabeled.
# File 2430.mat is successfully unlabeled.
# File 1139.mat is successfully unlabeled.
# File 2356.mat is successfully unlabeled.
# File 3048.mat is successfully unlabeled.
# File 1677.mat is successfully unlabeled.
# File 3060.mat is successfully unlabeled.
# File 2418.mat is successfully unlabeled.
# File 485.mat is successfully unlabeled.
# File 1111.mat is successfully unlabeled.
# File 491.mat is successfully unlabeled.
# File 2381.mat is successfully unlabeled.
# File 2395.mat is successfully unlabeled.
# File 308.mat is successfully unlabeled.
# File 1844.mat is successfully unlabeled.
# File 320.mat is successfully unlabeled.
# File 446.mat is successfully unlabeled.
# File 452.mat is successfully unlabeled.
# File 334.mat is successfully unlabeled.
# File 2626.mat is successfully unlabeled.
# File 23.mat is successfully unlabeled.
# File 1449.mat is successfully unlabeled.
# File 2140.mat is successfully unlabeled.
# File 37.mat is successfully unlabeled.
# File 2632.mat is successfully unlabeled.
# File 1313.mat is successfully unlabeled.
# File 687.mat is successfully unlabeled.
# File 1475.mat is successfully unlabeled.
# File 1461.mat is successfully unlabeled.
# File 2168.mat is successfully unlabeled.
# File 693.mat is successfully unlabeled.
# File 1307.mat is successfully unlabeled.
# File 678.mat is successfully unlabeled.
# File 2183.mat is successfully unlabeled.
# File 2197.mat is successfully unlabeled.
# File 2829.mat is successfully unlabeled.
# File 2801.mat is successfully unlabeled.
# File 644.mat is successfully unlabeled.
# File 122.mat is successfully unlabeled.
# File 136.mat is successfully unlabeled.
# File 650.mat is successfully unlabeled.
# File 888.mat is successfully unlabeled.
# File 2752.mat is successfully unlabeled.
# File 917.mat is successfully unlabeled.
# File 1529.mat is successfully unlabeled.
# File 2746.mat is successfully unlabeled.
# File 1501.mat is successfully unlabeled.
# File 1515.mat is successfully unlabeled.
# File 1273.mat is successfully unlabeled.
# File 1298.mat is successfully unlabeled.
# File 2791.mat is successfully unlabeled.
# File 2785.mat is successfully unlabeled.
# File 730.mat is successfully unlabeled.
# File 2236.mat is successfully unlabeled.
# File 1059.mat is successfully unlabeled.
# File 2544.mat is successfully unlabeled.
# File 297.mat is successfully unlabeled.
# File 2578.mat is successfully unlabeled.
# File 1717.mat is successfully unlabeled.
# File 283.mat is successfully unlabeled.
# File 268.mat is successfully unlabeled.
# File 1918.mat is successfully unlabeled.
# File 254.mat is successfully unlabeled.
# File 532.mat is successfully unlabeled.
# File 526.mat is successfully unlabeled.
# File 240.mat is successfully unlabeled.
# Extraction and verification complete.
